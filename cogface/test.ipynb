# %%
from whispers import whispers
from node import plot_graph
import pickle
from Profile import Profile

# %%
#data = create_dummy(10)
#graph, adj_mat = whispers(data, 0.5)

#plot_graph(graph, adj_mat)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

with open(r"database.pkl", mode="rb") as db:
    database = pickle.load(db)

input = database["Hyojae"].descriptors + database["Jacob"].descriptors + database["Joseph"].descriptors + database["Kathryn"].descriptors + database["Dharshini"].descriptors[0:4] + database["Angelina"].descriptors[0:4]


graph, adj_mat, cluster_count = whispers(input, 0.5)
for i in range(len(input)):
    print("ID: ", graph[i].id, " LABEL: ", graph[i].label)

fig, ax = plt.subplots()

ax.plot(np.arange(len(cluster_count)), cluster_count)
ax.grid()

plot_graph(graph, adj_mat)
# Out:
# stopping due to stopping point
# ID:  0  LABEL:  4
# ID:  1  LABEL:  4
# ID:  2  LABEL:  4
# ID:  3  LABEL:  4
# ID:  4  LABEL:  4
# ID:  5  LABEL:  9
# ID:  6  LABEL:  9
# ID:  7  LABEL:  9
# ID:  8  LABEL:  9
# ID:  9  LABEL:  9
# ID:  10  LABEL:  10
# ID:  11  LABEL:  13
# ID:  12  LABEL:  13
# ID:  13  LABEL:  13
# ID:  14  LABEL:  13
# ID:  15  LABEL:  17
# ID:  16  LABEL:  17
# ID:  17  LABEL:  17
# ID:  18  LABEL:  17
# ID:  19  LABEL:  22
# ID:  20  LABEL:  22
# ID:  21  LABEL:  22
# ID:  22  LABEL:  22
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)
